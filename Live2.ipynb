# %%
import pandas as pd
import pycaret
from pycaret.datasets import get_data

# %%
get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
df = get_data('employee')
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years department  \
# 0                   3              0                      0      sales
# 1                   6              0                      0      sales
# 2                   4              0                      0      sales
# 3                   5              0                      0      sales
# 4                   3              0                      0      sales
#
#    salary  left
# 0     low     1
# 1  medium     1
# 2  medium     1
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years department  \
# 0                   3              0                      0      sales
# 1                   6              0                      0      sales
# 2                   4              0                      0      sales
# 3                   5              0                      0      sales
# 4                   3              0                      0      sales
#
#    salary  left
# 0     low     1
# 1  medium     1
# 2  medium     1
# ...

# %% [markdown]
# O objetivo do case seria relacionado a saber se o funcionário vai deixar a empresa ou não.

# %% [markdown]
# # 2.2 Sanity checking

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.isna().sum().any()
# Out:
# False

# %%
import missingno as msno

# %%
msno.bar(df, figsize=(13, 3))
# Out:
# <AxesSubplot:>

# %%
df.nunique()
# Out:
# satisfaction_level        92
# last_evaluation           65
# number_project             6
# average_montly_hours     215
# time_spend_company         8
# Work_accident              2
# promotion_last_5years      2
# department                10
# salary                     3
# left                       2
# dtype: int64

# %%
df.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# promotion_last_5years      int64
# department                object
# salary                    object
# left                       int64
# dtype: object

# %% [markdown]
# ## 2.3 Análise de dados exploratória - (EDA - Exploratory Data Analyse)

# %% [markdown]
# ## 2.3.1 Target

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['left'])
# Out:
# pandas.core.series.Series

# %%
df['left'].value_counts() #Essa função dá os números de cada coisa
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
df['left'].value_counts(normalize=True) #Entrega o valor em percentual
# Out:
# 0    0.761917
# 1    0.238083
# Name: left, dtype: float64

# %%
import seaborn as sns

# %%
sns.countplot(data=df, y='left'); #A utilização do ponto e virgula retira o tipo ele na apresentação da saída

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident  \
# count          14999.000000        14999.000000   14999.000000
# mean             201.050337            3.498233       0.144610
# std               49.943099            1.460136       0.351719
# min               96.000000            2.000000       0.000000
# 25%              156.000000            3.000000       0.000000
# ...

# %%
df.plot(kind='box', figsize=(14,5), rot=45 )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2.3.3 Variáveis cateóricas()

# %%
pd.crosstab(df['salary'], df['left'], margins=True)
# Out:
# left        0     1    All
# salary
# high     1155    82   1237
# low      5144  2172   7316
# medium   5129  1317   6446
# All     11428  3571  14999

# %%
pd.crosstab(df['salary'], df['left'], normalize='index')
# Out:
# left           0         1
# salary
# high    0.933711  0.066289
# low     0.703116  0.296884
# medium  0.795687  0.204313

# %% [markdown]
# # 3. Preparação de ABT (Analytical base table)

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years department  \
# 0                   3              0                      0      sales
# 1                   6              0                      0      sales
# 2                   4              0                      0      sales
# 3                   5              0                      0      sales
# 4                   3              0                      0      sales
#
#    salary  left
# 0     low     1
# 1  medium     1
# 2  medium     1
# ...

# %%
df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
pd.get_dummies(df, columns=['department'])
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       157                   3              0
# 1                       262                   6              0
# 2                       272                   4              0
# ...
